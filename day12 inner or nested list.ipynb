# %% [markdown]
# ![image.png](attachment:d783b980-23b5-4347-9cd6-e971ba39f1d7.png)

# %% [markdown]
# ![image.png](attachment:26bc373b-be93-4408-82f1-b2a2df5d1e58.png)

# %% [markdown]
# ![image.png](attachment:f3ad1f49-6923-4f68-8467-7fe66ec647a1.png)

# %% [markdown]
# ![image.png](attachment:8cf47576-20ab-4f1a-ab1f-f76e43b436c7.png)

# %%
#inner or Nested list:-----
#syntax:-    listobj=[val1,val2.......[val11,val12,....val1n],[val21,val22,..val2.],val-n]
lst=[100,"karthik",[18,16,20],[76,75,66],"OUCET"]
print(lst,type(lst))
# Out:
# [100, 'karthik', [18, 16, 20], [76, 75, 66], 'OUCET'] <class 'list'>

# %%
lst[-1]
# Out:
# 'OUCET'

# %%
lst[-2]
# Out:
# [76, 75, 66]

# %%
lst[-3]
# Out:
# [18, 16, 20]

# %%
lst[1]
# Out:
# 'karthik'

# %%
lst[0]
# Out:
# 100

# %%
print(lst[2],type(lst),id(lst[2]))
# Out:
# [18, 16, 20] <class 'list'> 1986848787904

# %%
print(lst[-2],type(lst),id(lst[-2]))
# Out:
# [76, 75, 66] <class 'list'> 1986848798656

# %%
lst[2][0]
# Out:
# 18

# %%
lst[2][1]
# Out:
# 16

# %%
print(lst)
# Out:
# [100, 'karthik', [18, 16, 20], [76, 75, 66], 'OUCET']

# %%
lst[2].append(16)
print(lst)
# Out:
# [100, 'karthik', [18, 16, 20, 16], [76, 75, 66], 'OUCET']

# %%
lst=[100, 'karthik', [18, 16, 20, 16], [76, 75, 66], 'OUCET']
lst[-2].insert(-2,80)
print(lst)
# Out:
# [100, 'karthik', [18, 16, 20, 16], [76, 80, 75, 66], 'OUCET']

# %%
del lst[-2]
print(lst)
# Out:
# [100, 'karthik', [18, 16, 20, 16], 'OUCET']

# %%
lst[2].clear()
print(lst)
# Out:
# [100, 'karthik', [], 'OUCET']

# %%
del lst[2]
print(lst)
# Out:
# [100, 'karthik', 'OUCET']

# %%
lst.insert(2,[16,15,18,17])
print(lst)
# Out:
# [100, 'karthik', [16, 15, 18, 17], 'OUCET']

# %%
lst.insert(-1,[77,66,78,55])
print(lst)
# Out:
# [100, 'karthik', [16, 15, 18, 17], [77, 66, 78, 55], 'OUCET']

# %%
lst[2].sort()
print(lst)
# Out:
# [100, 'karthik', [15, 16, 17, 18], [77, 66, 78, 55], 'OUCET']

# %%
lst[2].sort(reverse=True)
print(lst)
# Out:
# [100, 'karthik', [18, 17, 16, 15], [77, 66, 78, 55], 'OUCET']

# %%
studlst=[100,"Dlprince",[18,16,19],[78,66,79],"OUCET"]
print(studlst,type(studlst))
# Out:
# [100, 'Dlprince', [18, 16, 19], [78, 66, 79], 'OUCET'] <class 'list'>

# %%
print(studlst[2],type(studlst[2]))
print(studlst[-2],type(studlst[-2]))
# Out:
# [18, 16, 19] <class 'list'>
# [78, 66, 79] <class 'list'>

# %%
studlst[-3].append(17)
print(studlst)
# Out:
# [100, 'Dlprince', [18, 16, 19, 17], [78, 66, 79], 'OUCET']

# %%
studlst[3].append(68)
print(studlst)
# Out:
# [100, 'Dlprince', [18, 16, 19, 17], [78, 66, 79, 68], 'OUCET']

# %%
studlst[2].sort()
print(studlst)
# Out:
# [100, 'Dlprince', [16, 17, 18, 19], [78, 66, 79, 68], 'OUCET']

# %%
studlst[3].sort(reverse=True)
print(studlst)
# Out:
# [100, 'Dlprince', [16, 17, 18, 19], [79, 78, 68, 66], 'OUCET']

# %%
studlst[2].pop(-2)
print(studlst)
# Out:
# [100, 'Dlprince', [16, 19], [79, 78, 66], 'OUCET']

# %%
studlst[-2].remove(68)
print(studlst)
# Out:
# [100, 'Dlprince', [16, 17, 19], [79, 78, 66], 'OUCET']

# %%
studlst[2].clear()
print(studlst)
# Out:
# [100, 'Dlprince', [], [79, 78, 66], 'OUCET']

# %%
studlst[2].append(14)
print(studlst,type(studlst))
# Out:
# [100, 'Dlprince', [14], [79, 78, 66], 'OUCET'] <class 'list'>

# %%
del studlst[2]
print(studlst)
# Out:
# [100, 'Dlprince']

# %%
del studlst[-2]
print(studlst)
# Out:
# ['Dlprince']

# %%
studlst.insert(2,[17,15,14,19])
print(studlst,type(studlst))
# Out:
# ['Dlprince', [17, 15, 14, 19], [17, 15, 14, 19]] <class 'list'>

# %%
len(studlst)
# Out:
# 3

# %%
len(studlst[2])
# Out:
# 4

# %%
len(studlst[-1])
# Out:
# 4
