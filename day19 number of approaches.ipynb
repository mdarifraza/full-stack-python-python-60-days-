# %% [markdown]
# ![image.png](attachment:7483a247-76ee-43e6-b9b0-26983e9756b8.png)

# %% [markdown]
# ![image.png](attachment:c7824373-8ef0-496c-bf87-63fd2283fa36.png)

# %% [markdown]
# program for computing sum of two numbers:

# %%
a=18
b=28
c=a+b
print("--------------")
print("value of a",a)
print("value of b",b)
print("sum",c)
print("--------------")
# Out:
# --------------
# value of a 18
# value of b 28
# sum 46
# --------------

# %% [markdown]
# multipication of two numbers

# %%
a=int(input("enter a value of a:"))
b=int(input("enter a value of b:"))
c=a*b
print("*"*20)
print("value of a:",a)
print("value of b:",b)
print("multiply",c)
print("*"*20)
# Out:
# enter a value of a: 85
# enter a value of b: 15
# ********************
# value of a: 85
# value of b: 15
# multiply 1275
# ********************
