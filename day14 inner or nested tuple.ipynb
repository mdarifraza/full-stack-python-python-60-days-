# %% [markdown]
# ![image.png](attachment:0c5ae8d4-d6e5-4067-b84e-2bc0d434c693.png)

# %% [markdown]
# ![image.png](attachment:70d96c86-d41d-4d3c-b750-a9fe0011b4f9.png)

# %% [markdown]
# ![image.png](attachment:4fdd3494-d06b-47b5-ad1d-4979a706e05f.png)

# %% [markdown]
# ![image.png](attachment:687a3c35-80b2-4aee-b54a-96b308c5c393.png)

# %% [markdown]
# inner or nested tuple:-

# %%
#syntax:-    tplobj=(val1,val2....(val11,val12..val11n).......(val21,val22,....val22n).....val-n
sf=(10,"Rs",(17,18,16),(78,66,79),"Oucet")
print(sf,type(sf))
# Out:
# (10, 'Rs', (17, 18, 16), (78, 66, 79), 'Oucet') <class 'tuple'>

# %%
print(sf[0])
# Out:
# 10

# %%
print(sf[2],type(sf[2]),type(sf))
# Out:
# (17, 18, 16) <class 'tuple'> <class 'tuple'>

# %%
print(sf[0:3])
# Out:
# (10, 'Rs', (17, 18, 16))

# %%
print(sf)
# Out:
# (10, 'Rs', (17, 18, 16), (78, 66, 79), 'Oucet')

# %%
sf=(10,"rs",[17,18,16],(78,66,79),"oucet")
print(sf[2],type(sf[2]),sf)
# Out:
# [17, 18, 16] <class 'list'> (10, 'rs', [17, 18, 16], (78, 66, 79), 'oucet')

# %%
sf[2].append(12)
print(sf[2],type(sf[2]),type(sf))
# Out:
# [17, 18, 16, 12, 12] <class 'list'> <class 'tuple'>

# %%
sf[3].append(12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sf[3].append(12)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1=(10,"rossum",[16,18,17],("cse","ai","ds"),"oucet")
print(t1,type(t1))
# Out:
# (10, 'rossum', [16, 18, 17], ('cse', 'ai', 'ds'), 'oucet') <class 'tuple'>

# %%
print(t1[2],type(t1[2]))
# Out:
# [16, 18, 17] <class 'list'>

# %%
print(t1[3]),type(t1[3])
# Out:
# ('cse', 'ai', 'ds')
# (None, tuple)

# %%
t1[2].append("kvr")
print(t1,type(t1))
# Out:
# (10, 'rossum', [16, 18, 17, 'kvr', 'kvr'], ('cse', 'ai', 'ds'), 'oucet') <class 'tuple'>

# %%
t1[3].append("python")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 t1[3].append("python")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1[2][1]
# Out:
# 18

# %%
t1[2][-2]
# Out:
# 'kvr'

# %%
k=sorted(t1[-2])

# %%
print(k)
# Out:
# ['ai', 'cse', 'ds']

# %%
t1[3]=k
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 t1[3]=k
#
# TypeError: 'tuple' object does not support item assignment

# %%
l1=list(t1)

# %%
l1=[10,"rossum",[16,18,17,"kvr"],("cse","ai","ds"),"oucet"]
l1[3]=k
print(l1)
# Out:
# [10, 'rossum', [16, 18, 17, 'kvr'], ['ai', 'cse', 'ds'], 'oucet']

# %%
y=tuple(l1[3])
l1[3]=y

# %%
print(l1)
# Out:
# [10, 'rossum', [16, 18, 17, 'kvr'], ('ai', 'cse', 'ds'), 'oucet']

# %%
t2=tuple(l1)
print(t2)
# Out:
# (10, 'rossum', [16, 18, 17, 'kvr'], ('ai', 'cse', 'ds'), 'oucet')

# %%
t1=("ai","cs","ds")
k=sorted(t1)
print(k)
# Out:
# ['ai', 'cs', 'ds']
